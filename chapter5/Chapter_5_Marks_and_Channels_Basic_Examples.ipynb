# %% [markdown]
# <a href="https://colab.research.google.com/github/sunshineluyao/vis-basics/blob/main/Chapter_5_Marks_and_Channels_Basic_Examples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter 5: Marks and Channels
#
# ## Overview
# In this chapter, you will learn about the building blocks of visual encodings: **marks** (basic geometric elements) and **channels** (ways to modify the appearance of marks). Understanding these concepts is essential for analyzing and designing effective visualizations.
#
# ---
#
# ## Section 5.1: The Big Picture
# ### Learning Outcome
# Understand the distinction between marks and channels and how the expressiveness of channels impacts data representation.
#
# ### Case in Google Colab
# **Case 1:** Create basic marks such as points, lines, and areas using `matplotlib` and modify their appearance using visual channels like color, size, and shape.
# ```python
# import matplotlib.pyplot as plt
#
# # Creating marks: points
# x = [1, 2, 3, 4, 5]
# y = [2, 3, 4, 5, 6]
# sizes = [20, 50, 80, 110, 140]  # Size channel
# colors = ['red', 'green', 'blue', 'orange', 'purple']  # Color channel
#
# plt.scatter(x, y, s=sizes, c=colors)
# plt.title("Points with Different Sizes and Colors")
# plt.xlabel("X-axis")
# plt.ylabel("Y-axis")
# plt.show()
# ```
# **Explanation:** This case demonstrates how to apply visual channels (size and color) to point marks.
#
# ---
#
# ## Section 5.2: Why Marks and Channels?
# ### Learning Outcome
# Analyze the design space of visual encodings using marks and channels.
#
# ### Case in Google Colab
# **Case 2:** Design a scatter plot and explore the effect of encoding data attributes with different channels.
# ```python
# import numpy as np
#
# # Simulating data
# np.random.seed(0)
# x = np.random.rand(50)
# y = np.random.rand(50)
# area = (30 * np.random.rand(50))**2  # Size channel
# color = np.random.rand(50)  # Color channel
#
# plt.scatter(x, y, s=area, c=color, alpha=0.5, cmap='viridis')
# plt.colorbar()
# plt.title("Scatter Plot with Size and Color Channels")
# plt.xlabel("X-axis")
# plt.ylabel("Y-axis")
# plt.show()
# ```
# **Explanation:** This case shows how different channels can be used to enhance the scatter plot's information content.
#
# ---
#
# ## Section 5.3: Defining Marks and Channels
# ### Learning Outcome
# Define marks and understand their types (0D points, 1D lines, 2D areas) and the channels that modify their appearance.
#
# ### Case in Google Colab
# **Case 3:** Visualize different mark types and use various channels to encode information.
# ```python
# # Creating marks: lines and areas
# x = np.linspace(0, 10, 100)
# y1 = np.sin(x)
# y2 = np.cos(x)
#
# plt.plot(x, y1, label='Sin(x)', linewidth=2.5)  # Line mark with size channel
# plt.fill_between(x, y1, y2, color='lightblue', alpha=0.5)  # Area mark with color channel
# plt.plot(x, y2, label='Cos(x)', linewidth=1.5, linestyle='--')  # Line mark with style channel
#
# plt.title("Line and Area Marks with Channels")
# plt.xlabel("X-axis")
# plt.ylabel("Y-axis")
# plt.legend()
# plt.show()
# ```
# **Explanation:** Here, you’ll see how to define and modify line and area marks with channels like linewidth, color, and style.
#
# ---
#
# ## Section 5.4: Using Marks and Channels
# ### Learning Outcome
# Learn to use expressiveness and effectiveness principles to choose the best visual channels for encoding data.
#
# ### Case in Google Colab
# **Case 4:** Compare the effectiveness of different channels (e.g., spatial position vs. color) using bar and scatter plots.
# ```python
# # Bar chart example
# categories = ['A', 'B', 'C', 'D']
# values = [4, 7, 2, 5]
# colors = ['#FF5733', '#33FF57', '#3357FF', '#F3FF33']  # Using color channel
#
# plt.bar(categories, values, color=colors)
# plt.title("Bar Chart Using Color Channel")
# plt.xlabel("Categories")
# plt.ylabel("Values")
# plt.show()
# ```
# **Explanation:** This case illustrates how to use visual channels in bar charts and emphasizes the choice of effective channels.
#
# ---
#
# ## Section 5.5: Channel Effectiveness
# ### Learning Outcome
# Explore the criteria for evaluating channel effectiveness, such as accuracy and discriminability.
#
# ### Case in Google Colab
# **Case 5:** Simulate a comparison of accuracy for different visual channels.
# ```python
# # Simulating accuracy perception
# lengths = [5, 7, 9, 11]
# labels = ['L1', 'L2', 'L3', 'L4']
#
# plt.figure(figsize=(10, 2))
# plt.barh(labels, lengths, color='teal')
# plt.title("Perceptual Accuracy of Length Channel")
# plt.xlabel("Length")
# plt.show()
# ```
# **Explanation:** This case visually represents how well humans can perceive differences in length, emphasizing the accuracy of spatial position and size.

# %%
import matplotlib.pyplot as plt

# Creating marks: points
x = [1, 2, 3, 4, 5]
y = [2, 3, 4, 5, 6]
sizes = [20, 50, 80, 110, 140]  # Size channel
colors = ['red', 'green', 'blue', 'orange', 'purple']  # Color channel

plt.scatter(x, y, s=sizes, c=colors)
plt.title("Points with Different Sizes and Colors")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
import numpy as np

# Simulating data
np.random.seed(0)
x = np.random.rand(50)
y = np.random.rand(50)
area = (30 * np.random.rand(50))**2  # Size channel
color = np.random.rand(50)  # Color channel

plt.scatter(x, y, s=area, c=color, alpha=0.5, cmap='viridis')
plt.colorbar()
plt.title("Scatter Plot with Size and Color Channels")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
# Creating marks: lines and areas
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

plt.plot(x, y1, label='Sin(x)', linewidth=2.5)  # Line mark with size channel
plt.fill_between(x, y1, y2, color='lightblue', alpha=0.5)  # Area mark with color channel
plt.plot(x, y2, label='Cos(x)', linewidth=1.5, linestyle='--')  # Line mark with style channel

plt.title("Line and Area Marks with Channels")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend()
plt.show()

# %%
# Bar chart example
categories = ['A', 'B', 'C', 'D']
values = [4, 7, 2, 5]
colors = ['#FF5733', '#33FF57', '#3357FF', '#F3FF33']  # Using color channel

plt.bar(categories, values, color=colors)
plt.title("Bar Chart Using Color Channel")
plt.xlabel("Categories")
plt.ylabel("Values")
plt.show()

# %%
# Simulating accuracy perception
lengths = [5, 7, 9, 11]
labels = ['L1', 'L2', 'L3', 'L4']

plt.figure(figsize=(10, 2))
plt.barh(labels, lengths, color='teal')
plt.title("Perceptual Accuracy of Length Channel")
plt.xlabel("Length")
plt.show()
